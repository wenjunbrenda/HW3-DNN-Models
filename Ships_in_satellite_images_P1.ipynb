# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = "Wenjun Wang"
COLLABORATORS = "（None)"

# %% [markdown]
# ---

# %% [markdown]
# # Problem description
#
# To a large degree, financial data has traditionally been numeric in format.
#
# But in recent years, non-numeric formats like image, text and audio have been introduced.
#
# Private companies have satellites orbiting the Earth taking photos and offering them to customers.  A financial analyst might be able to extract information from these photos that could aid in the prediction of the future price of a stock
#
# - Approximate number of customers visiting each store: count number of cars in parking lot
# - Approximate activity in a factory by counting number of supplier trucks arriving and number of delivery trucks leaving
# - Approximate demand for a commodity at each location: count cargo ships traveling between ports
#
# In this assignment, we will attempt to recognize ships in satellite photos.
# This would be a first step toward
# counting.
#
# As in any other domain: specific knowledge of the problem area will make you a better analyst.
#
# For this assignment, we will ignore domain-specific information and just try to use a labeled training set (photo plus a binary indicator for whether a ship is present/absent in the photo), assuming that the labels are perfect.

# %% [markdown]
# ## Goal:
#
# In this notebook, you will need to create a model in `TensorFlow/Keras` to classify satellite photos.
# - The features are images: 3 dimensional collection of pixels
#   - 2 spatial dimensions
#   - 1 dimension with 3 features for different parts of the color spectrum: Red, Green, Blue
# - The labels are either 1 (ship is present) or 0 (ship is not present)
#
# There are two notebook files in this assignment:
# - The one you are viewing now: First and only notebook you need to work on.
#     - Train your models here
#     - There are cells that will save your models to a file
# - **`Model_test.ipynb`**:
#     - PLEASE IGNORE
#
# You will create several Keras `Sequential` models, of increasing complexity
# - A model that implements only a Classification Head (no transformations other than perhaps rearranging the image)
# - A model that adds a Dense layer before the head
# - (Later assignment) A model that adds Convolutional layers before the Head

# %% [markdown]
# ## Learning objectives
# - Learn how to construct Neural Networks using Keras Sequential model
# - Appreciate how layer choices impact number of weights

# %% [markdown]
# # Imports modules

# %%
## Standard imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import sklearn

import os
import math

# %matplotlib inline


## Import tensorflow and check the version
import tensorflow as tf
from tensorflow.keras.utils import plot_model

print("Running TensorFlow version ",tf.__version__)

# Parse tensorflow version
import re

version_match = re.match("([0-9]+)\.([0-9]+)", tf.__version__)
tf_major, tf_minor = int(version_match.group(1)) , int(version_match.group(2))
print("Version {v:d}, minor {m:d}".format(v=tf_major, m=tf_minor) )
# Out:
# Running TensorFlow version  2.3.1
# Version 2, minor 3

# %% [markdown]
# # API for students
#
# We have defined some utility routines in a file `helper.py`. There is a class named `Helper` in it.
#
# This will simplify problem solving
#
# More importantly: it adds structure to your submission so that it may be easily graded
#
# `helper = helper.Helper()`
#
# - getData: Get a collection of labeled images, used as follows
#
#   >`data, labels = helper.getData()`
# - showData: Visualize labelled images, used as follows
#
#   >`helper.showData(data, labels)`
# - plot training results: Visualize training accuracy, loss and validation accuracy, loss
#
#   >`helper.plotTrain(history, modelName)`, where history is the result of model training
# - save model: save a model in `./models` directory
#
#   >`helper.saveModel(model, modelName)`
# - save history: save a model history in `./models` directory
#   >`helper.saveHistory(history, modelName)`

# %%
# Load the helper module
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# Reload all modules imported with %aimport
# %reload_ext autoreload
# %autoreload 1

# Import nn_helper module
import helper
# %aimport helper

helper = helper.Helper()

# %% [markdown]
# # Get the data
#
# The first step in our Recipe is Get the Data.
#
# We have provided a utility method `getData` to simplify this for you

# %%
# Get the data
data, labels = helper.getData()
n_samples, width, height, channel = data.shape

print("Data shape: ", data.shape)
print("Labels shape: ", labels.shape)
print("Label values: ", np.unique(labels))
# Out:
# Data shape:  (4000, 80, 80, 3)
# Labels shape:  (4000,)
# Label values:  [0 1]

# %% [markdown]
# We will shuffle the examples before doing anything else.
#
# This is usually a good idea
# - Many datasets are naturally arranged in a *non-random* order, e.g., examples with the sample label grouped together
# - You want to make sure that, when you split the examples into training and test examples, each split has a similar distribution of examples

# %%
# Shuffle the data first
data, labels = sklearn.utils.shuffle(data, labels, random_state=42)

# %% [markdown]
# ## Have a look at the data
#
# We will not go through all steps in the Recipe, nor in depth.
#
# But here's a peek

# %%
# Visualize the data samples
helper.showData(data[:25], labels[:25])

# %% [markdown]
# ## Eliminate the color dimension
#
# As a simplification, we will convert the image from color (RGB, with 3 "color" dimensions referred to as Red, Green and Blue) to gray scale.

# %%
print("Original shape of data: ", data.shape)

w = (.299, .587, .114)
data_bw = np.sum(data *w, axis=3)

print("New shape of data: ", data_bw.shape)

data_orig = data.copy()
# Out:
# Original shape of data:  (4000, 80, 80, 3)
# New shape of data:  (4000, 80, 80)

# %%
# Visualize the data samples
helper.showData(data_bw[:25], labels[:25], cmap="gray")

# %% [markdown]
# ## Have  look at the data: Examine the image/label pairs
#
# Rather than viewing the examples in random order, let's group them by label.
#
# Perhaps we will learn something about the characteristics of images that contain ships.
#
# We have loaded and shuffled our dataset, now we will take a look at image/label pairs.
#
# Feel free to explore the data using your own ideas and techniques.

# %%
# Inspect some data (images)
num_each_label = 10

for lab in np.unique(labels):
    # Fetch images with different labels
    X_lab, y_lab = data_bw[ labels == lab ], labels[ labels == lab]
    # Display images
    fig = helper.showData( X_lab[:num_each_label], [ str(label) for label in y_lab[:num_each_label] ], cmap="gray")
    _ = fig.suptitle("Label: "+  str(lab), fontsize=14)
    print("\n\n")

# %% [markdown]
# # Make sure the features are in the range [0,1]
#
# **Warm up exercise:** When we want to train image data, the first thing we usually need to do is scaling.
#
# Since the feature values in our image data are between 0 and 255, to make them between 0 and 1, we need to divide them by 255.
#
# We also need to consider how to represent our target values
# - If there are more than 2 possible target values, One Hot Encoding may be appropriate
#     - **Hint**: Lookup `tf.keras.utils.to_categorical`
# - If there are only 2 possible targets with values 0 and 1 we can use these targets without further encoding
#
# **Question**
# - Set variable `X` to be our gray-scale examples (`data_bw`), but with values in the range [0,1]
# - Set variable `y` to be the representation of our target values

# %%
# Scale the data
# Assign values for X, y
#  X: the array of features
#  y: the array of labels
# The length of X and y should be identical and equal to the length of data.
from tensorflow.keras.utils import to_categorical
X, y = np.array([]), np.array([])

# YOUR CODE HERE
X=data_bw/255
y=labels
## double-check unique target values:
check_labels=np.unique(labels)
print(check_labels)
# Out:
# [0 1]

# %%
## Based on the np.unique values checking result, this database only has two target values, thus One Hot Encoding processing would not need to apply.

# %%
X #for double check
# Out:
# array([[[0.23386275, 0.23778431, 0.23503529, ..., 0.2634902 ,
#          0.25726667, 0.25104314],
#         [0.23571765, 0.25969412, 0.24954902, ..., 0.26029412,
#          0.25451765, 0.25338824],
#         [0.2486549 , 0.26591765, 0.25302353, ..., 0.2474    ,
#          0.23652941, 0.24946667],
#         ...,
#         [0.25306667, 0.25767059, 0.25140392, ..., 0.26082745,
#          0.24816863, 0.25876078],
#         [0.25884314, 0.26276471, 0.25649804, ..., 0.2615098 ,
#          0.26425882, 0.25758824],
#         [0.25217255, 0.25884314, 0.25722353, ..., 0.28269412,
#          0.29401176, 0.26425882]],
#
#        [[0.44977647, 0.52432941, 0.55150196, ..., 0.44714118,
#          0.57429412, 0.62700392],
#         [0.40955686, 0.44007843, 0.40243922, ..., 0.45886275,
#          0.54590588, 0.62510588],
#         [0.4091098 , 0.32743922, 0.28183137, ..., 0.47188235,
#          0.50587843, 0.5564549 ],
#         ...,
#         [0.5537451 , 0.54287451, 0.52068627, ..., 0.4760549 ,
#          0.46377647, 0.38272157],
#         [0.49189412, 0.44641176, 0.4198549 , ..., 0.58283137,
#          0.57168235, 0.47643529],
#         [0.49626275, 0.43351765, 0.2963451 , ..., 0.64182353,
#          0.63487451, 0.49442353]],
#
#        [[0.28615294, 0.28615294, 0.31846275, ..., 0.2884549 ,
#          0.29702353, 0.31068627],
#         [0.28295686, 0.29634118, 0.32238431, ..., 0.26581961,
#          0.28408627, 0.30906667],
#         [0.28020784, 0.29241961, 0.27807451, ..., 0.28267843,
#          0.2783098 , 0.30441961],
#         ...,
#         [0.28732549, 0.2908    , 0.28570588, ..., 0.27551765,
#          0.2743451 , 0.27826667],
#         [0.29124706, 0.28962745, 0.27786275, ..., 0.28525882,
#          0.2866    , 0.28542745],
#         [0.28732549, 0.28340392, 0.27276863, ..., 0.27511373,
#          0.28777255, 0.27762745]],
#
#        ...,
#
#        [[0.19207451, 0.18977255, 0.1784549 , ..., 0.19987451,
#          0.16345098, 0.1584    ],
#         [0.17638824, 0.18540392, 0.19531373, ..., 0.19550588,
#          0.17751765, 0.15100392],
#         [0.19392941, 0.19599608, 0.20938039, ..., 0.1763451 ,
#          0.17359608, 0.14708235],
#         ...,
#         [0.22551373, 0.19806275, 0.18237647, ..., 0.17800784,
#          0.17918039, 0.18035294],
#         [0.19919216, 0.19296863, 0.19644314, ..., 0.17918039,
#          0.17918039, 0.18427451],
#         [0.18698039, 0.18540392, 0.20776078, ..., 0.17918039,
#          0.18148235, 0.18310196]],
#
#        [[0.23460392, 0.23213333, 0.29176471, ..., 0.22865882,
#          0.24176471, 0.22058039],
#         [0.27247843, 0.2930902 , 0.31197255, ..., 0.22469412,
#          0.22793333, 0.21184314],
#         [0.38648235, 0.44692549, 0.43072549, ..., 0.22077255,
#          0.21135294, 0.22518431],
#         ...,
#         [0.22098431, 0.24204314, 0.27936078, ..., 0.20210196,
#          0.20949804, 0.24361961],
#         [0.23505098, 0.27309412, 0.29937255, ..., 0.1898902 ,
#          0.18091765, 0.21661569],
#         [0.25231373, 0.26755294, 0.27887059, ..., 0.20323137,
#          0.21936471, 0.23897255]],
#
#        [[0.44003137, 0.44742745, 0.43012157, ..., 0.43035686,
#          0.42413333, 0.42692549],
#         [0.42984314, 0.43566275, 0.42894902, ..., 0.43427843,
#          0.43314902, 0.42647843],
#         [0.43723922, 0.43287059, 0.4262    , ..., 0.4405451 ,
#          0.43824314, 0.42647843],
#         ...,
#         [0.44329412, 0.44261176, 0.43359608, ..., 0.4344902 ,
#          0.4215098 , 0.42543137],
#         [0.43197647, 0.44536078, 0.43521569, ..., 0.43331765,
#          0.4321451 , 0.41803529],
#         [0.40497255, 0.42692549, 0.42575294, ..., 0.42939608,
#          0.43331765, 0.422     ]]])

# %%
# Check if your solution is right 

assert X.shape == (4000, 80, 80)
assert y.shape == (4000,)

# %% [markdown]
# # Split data into training data and testing data
# To train and evaluate a model, we need to split the original dataset into
# a training subset (in-sample) and a test subset (out of sample).
#
# We will do this for you in the cell below.
#
# **DO NOT** shuffle the data until after we have performed the split into train/test sets
# - We want everyone to have the **identical** test set for grading
# - Do not change this cell

# %%
# Split data into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=42)

# Save X_train, X_test, y_train, y_test for final testing
if not os.path.exists('./data'):
    os.mkdir('./data')
np.savez_compressed('./data/train_test_data.npz', X_train=X_train, X_test=X_test, y_train=y_train, y_test=y_test)

# %% [markdown]
# # Create a model using only Classification, no data transformation (other than reshaping)
#
# **Question:** You need to build a 1-layer (head layer only) network model with `tensorflow.keras`. Please name the head layer "dense_head".
#
# Set variable `model0` to be a Keras `Sequential` model object that implements your model.
#
# **Hints:**
# 1. Since the dataset is 2-dimensional, you may want to use `Flatten()` in `tensorflow.keras.layers` to make your input data 1 dimensional.
#     - The `input shape` argument of the `Flatten()` layer should be the shape of a single example
# 2. The number of units in your head layer
#     - Depends on how you represented the target
#     - It should be equal to the final dimension of  `y`
#
# 3. Activation function for the head layer: Since this is a classification problem
#     - Use  `sigmoid` if your target's final dimension equals 1
#     - Use  `softmax` if your target's final dimension is greater than 1
#
# - A Dropout layer maybe helpful to prevent overfitting and accelerate your training process.
#     - If you want to use a Dropout layer, you can use `Dropout()`, which is in  `tensorflow.keras.layers`.

# %%
import tensorflow as tf
from tensorflow import keras

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import plot_model
import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files (x86)/Graphviz 2.44.1/bin'

# %%
# Get the number of unique labels
num_cases = np.unique(labels).shape[0]
if num_cases > 2:
    activation = "softmax"
    loss = 'categorical_crossentropy'
else:
    activation = "sigmoid"
    num_cases = 1
    loss = 'binary_crossentropy'
    
# Set model0 equal to a Keras Sequential model
model0 = None

input_size = np.prod(X_train[0].shape)
output_size = np.unique(y_train).shape[0]

# YOUR CODE HERE
model0 = keras.Sequential([
    keras.layers.Flatten(input_shape=(80,80)), # transforms the format of the images from a 2-dimensional array to a 1-dimensional array
    # I know that the head layer output_size=2 using loss='sparse_categorical_crossentropy'; Since I choose loss='binary_crossentropy', thus here output_size is set to 1)
    keras.layers.Dense(1, activation='sigmoid',name="dense_head")]) # Head layer for classification

model0.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense_head (Dense)           (None, 1)                 6401
# =================================================================
# Total params: 6,401
# Trainable params: 6,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
# We can plot our model here using plot_model()
plot_model(model0)

# %% [markdown]
# ## Train model
#
# **Question:**
#
# Now that you have built your first model, you will compile and train it. The requirements are as follows:
#
# - Split the **training** examples `X_train, y_train` again !
#     - 80% will be used for training the model
#     - 20% will be used as validation (out of sample) examples
#     - Use `train_test_split()` from `sklearn` to perform this split
#         -  Set the `random_state` parameter of `train_test_split()` to be 42
#
# - Loss function:
#     - `binary_crossentropy` if your target is one-dimensional
#     - `categorical_crossentropy`if your target is One Hot Encoded
# - Metric: "accuracy"
# - Use exactly 15  epochs for training
# - Save your training results in a variable named `history0`
# - Plot your training results using the`plotTrain` method described in the Student API above.

# %%
y.shape
# Out:
# (4000,)

# %%
model_name0 = "Head only"

# YOUR CODE HERE
##from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
model_name="model0"
##es_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=.00005, patience=2, verbose=0, mode='auto', baseline=None, restore_best_weights=True)

##callbacks = [ es_callback,
##              ModelCheckpoint(filepath=modelName + ".ckpt", monitor='acc', save_best_only=True)
##          ]

## Split data into train and valid again:
X_train_1, X_valid, y_train_1, y_valid = train_test_split(X_train, y_train, test_size=0.20, random_state=42)


metrics = ['accuracy']
model0.compile(optimizer='adam',
                    loss='binary_crossentropy',
                    metrics=metrics)

n_epochs = 15
batch_size = 100
history0 =model0.fit(X_train_1, y_train_1, epochs=n_epochs, validation_data=(X_valid, y_valid),batch_size=batch_size)
# Out:
# Epoch 1/15
# 29/29 [==============================] - 0s 10ms/step - loss: 0.5502 - accuracy: 0.7514 - val_loss: 0.4346 - val_accuracy: 0.8153
# Epoch 2/15
# 29/29 [==============================] - 0s 4ms/step - loss: 0.4134 - accuracy: 0.8198 - val_loss: 0.4199 - val_accuracy: 0.8111
# Epoch 3/15
# 29/29 [==============================] - 0s 3ms/step - loss: 0.3880 - accuracy: 0.8326 - val_loss: 0.3758 - val_accuracy: 0.8333
# Epoch 4/15
# 29/29 [==============================] - 0s 4ms/step - loss: 0.3642 - accuracy: 0.8420 - val_loss: 0.3660 - val_accuracy: 0.8347
# Epoch 5/15
# 29/29 [==============================] - 0s 4ms/step - loss: 0.3734 - accuracy: 0.8399 - val_loss: 0.3903 - val_accuracy: 0.8639
# Epoch 6/15
# 29/29 [==============================] - 0s 4ms/step - loss: 0.3509 - accuracy: 0.8476 - val_loss: 0.3471 - val_accuracy: 0.8514
# Epoch 7/15
# 29/29 [==============================] - 0s 4ms/step - loss: 0.3402 - accuracy: 0.8573 - val_loss: 0.3392 - val_accuracy: 0.8569
# Epoch 8/15
# 29/29 [==============================] - 0s 4ms/step - loss: 0.3256 - accuracy: 0.8601 - val_loss: 0.3289 - val_accuracy: 0.8556
# Epoch 9/15
# 29/29 [==============================] - 0s 4ms/step - loss: 0.3227 - accuracy: 0.8681 - val_loss: 0.3234 - val_accuracy: 0.8500
# Epoch 10/15
# 29/29 [==============================] - 0s 4ms/step - loss: 0.3248 - accuracy: 0.8670 - val_loss: 0.3242 - val_accuracy: 0.8542
# Epoch 11/15
# 29/29 [==============================] - 0s 4ms/step - loss: 0.3139 - accuracy: 0.8667 - val_loss: 0.3323 - val_accuracy: 0.8569
# Epoch 12/15
# 29/29 [==============================] - 0s 4ms/step - loss: 0.3094 - accuracy: 0.8715 - val_loss: 0.3246 - val_accuracy: 0.8556
# Epoch 13/15
# 29/29 [==============================] - 0s 4ms/step - loss: 0.3080 - accuracy: 0.8747 - val_loss: 0.3143 - val_accuracy: 0.8597
# Epoch 14/15
# 29/29 [==============================] - 0s 4ms/step - loss: 0.3033 - accuracy: 0.8743 - val_loss: 0.3108 - val_accuracy: 0.8611
# Epoch 15/15
# 29/29 [==============================] - 0s 4ms/step - loss: 0.2996 - accuracy: 0.8722 - val_loss: 0.3096 - val_accuracy: 0.8597

# %%
import matplotlib.pyplot as plt

def plot_training(history, metrics=[]):
    """
    Plot training and validation statistics
    - accuracy vs epoch number
    - loss     vs epoch number

    From https://www.learnopencv.com/keras-tutorial-fine-tuning-using-pre-trained-models/
    """  

    # Loss
    loss = history.history['loss']

    epochs = range(len(loss))

    plt.plot(epochs, loss, 'b', label='Training loss')
    plt.title('Training loss')
    plt.legend()

    plt.figure()

    for metric in metrics:
      metric_value = history.history[metric]
      plt.plot(epochs, metric_value, 'b', label="Training " + metric)
      plt.title('Training  accuracy')
      plt.legend()

    plt.show()

# %%
history0.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
helper.plotTrain(history0,model_name)
# Out:
# (<Figure size 864x360 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000276A5D15B20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000276A5D15FA0>],
#        dtype=object))

# %%
plot_training(history0, metrics)

# %% [markdown]
# ## How many weights in the model ?
#
# **Question:**
#
# Calculate the number of parameters in your model.
#
# Set variable `num_parameters0` to be equal to the number of parameters in your model.
#
# **Hint:** The model object may have a method to help you ! Remember that Jupyter can help you find the methods that an object implements.

# %%
# Set num_parameters0 equal to the number of weights in the model
num_parameters0 = None

# YOUR CODE HERE
num_parameters0=model0.count_params()

print("Parameters number in model0: ", num_parameters0)
# Out:
# Parameters number in model0:  6401

# %% [markdown]
# ## Evaluate the model
#
# **Question:**
#
# We have trained our model. We now need to  evaluate the model using the test dataset created in an earlier cell.
#
# Please store the model score in a variable named `score0`.
#
# **Hint:** The model object has a method  `evaluate`.  Use that to compute the score.

# %%
score0 = []

# YOUR CODE HERE
score0=model0.evaluate(X_test,y_test)

print("{n:s}: Test loss: {l:3.2f} / Test accuracy: {a:3.2f}".format(n=model_name0, l=score0[0], a=score0[1]))
# Out:
# 13/13 [==============================] - 0s 775us/step - loss: 0.3036 - accuracy: 0.8850
# Head only: Test loss: 0.30 / Test accuracy: 0.88

# %% [markdown]
# ## Save the trained model0 and history0 for submission
#
# Your fitted model can be saved for later use
# - In general: so you can resume training at a later time
# - In particular: to allow us to grade it !
#
# Execute the following cell to save your model, which you will submit to us for grading.

# %%
helper.saveModel(model0, model_name0)
helper.saveHistory(history0, model_name0)
# Out:
# Directory .\models\Head only already exists, files will be over-written.
# Model saved in directory .\models\Head only; create an archive of this directory and submit with your assignment.
# Directory .\models\Head only already exists, files will be over-written.

# %% [markdown]
# **Question:**
#
# Make sure that the saved model can be successfully restored.
# - Set variable `model_loss` to the value of the loss parameter you used in the `compile` statement for your model
# - Set variable `model_metrics` to the value of the metrics parameter you used in the `compile` statement for  your model

# %%
## Restore the model (make sure that it works)

model_loss=None
model_metrics=None

# YOUR CODE HERE
model_loss='binary_crossentropy'
model_metrics=metrics

model_loaded = helper.loadModel(model_name0, loss=model_loss, metrics=model_metrics)
score_loaded = model_loaded.evaluate(X_test, y_test, verbose=0)

assert score_loaded[0] == score0[0] and score_loaded[1] == score0[1]

# %% [markdown]
# # Create a new model with an additional Dense layer
#
# **Question:**
#
# We will add more layers to the original model0.
#
# - You need to add **AT LEAST ONE** Dense layer followed by an activation function (for example, ReLU)
#     - You can add more layers if you like
#
# - The number of units in your very **FIRST** Dense layer should be equal to the value of variable `num_features_1`, as set below.
#     - Please name this Dense layer "dense_1" and the head layer "dense_head".
#
# **Hints:**
# - Don't forget to flatten your input data!
# - A Dropout layer maybe helpful to prevent overfitting and accelerate your training process.
#     - If you want to use a Dropout layer, you can use `Dropout()`, which is in  `tensorflow.keras.layers`.
#
# Hopefully your new model performs **better** than your first.

# %%
# Set model1 equal to a Keras Sequential model
model1 = None
num_features_1 = 32

# YOUR CODE HERE
model1=keras.Sequential([
    keras.layers.Flatten(input_shape=(80,80)), # transforms the format of the images from a 2-dimensional array to a 1-dimensional array
    keras.layers.Dense(num_features_1,activation='relu',name="dense_1"),
    # I know that the head layer output_size=2 using loss='sparse_categorical_crossentropy'; Since I choose loss='binary_crossentropy', thus here output_size is set to 1)
    keras.layers.Dense(1, activation='sigmoid',name="dense_head")]) # Head layer for classification

model1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                204832
# _________________________________________________________________
# dense_head (Dense)           (None, 1)                 33
# =================================================================
# Total params: 204,865
# Trainable params: 204,865
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Plot your model
plot_model(model1)

# %% [markdown]
# ## Train your new model
#
# **Question:**
#
# Now that you have built your new model1,  you will compile and train model1. The requirements are as follows:
#
# - Split the **training** examples `X_train, y_train` again !
#     - 80% will be used for training the model
#     - 20% will be used as validation (out of sample) examples
#     - Use `train_test_split()` from `sklearn` to perform this split
#         -  Set the `random_state` parameter of `train_test_split()` to be 42
#
# - Loss function: `categorical_crossentropy`; Metric: "accuracy"
# - Use exactly 15  epochs for training
# - Save your training results in a variable named `history1`
# - Plot your training results using the`plotTrain` method described in the Student API above.

# %%
# Train the model using the API
model_name1 = "Dense + Head"

# YOUR CODE HERE
Model_Name="model1"

## Split data into train and test again:
X_train_2, X_valid_2, y_train_2, y_valid_2 = train_test_split(X_train, y_train, test_size=0.20, random_state=42)


metrics = ['accuracy']
model1.compile(optimizer='adam',
                    loss='binary_crossentropy',
                    metrics=metrics)

n_epochs = 15
batch_size = 100
history1 =model1.fit(X_train_2, y_train_2, epochs=n_epochs, validation_data=(X_valid_2, y_valid_2), batch_size=batch_size)
# Out:
# Epoch 1/15
# 29/29 [==============================] - 0s 9ms/step - loss: 0.6067 - accuracy: 0.7469 - val_loss: 0.4480 - val_accuracy: 0.7958
# Epoch 2/15
# 29/29 [==============================] - 0s 4ms/step - loss: 0.4240 - accuracy: 0.8139 - val_loss: 0.4011 - val_accuracy: 0.8153
# Epoch 3/15
# 29/29 [==============================] - 0s 5ms/step - loss: 0.3881 - accuracy: 0.8340 - val_loss: 0.3766 - val_accuracy: 0.8278
# Epoch 4/15
# 29/29 [==============================] - 0s 4ms/step - loss: 0.3673 - accuracy: 0.8420 - val_loss: 0.3562 - val_accuracy: 0.8389
# Epoch 5/15
# 29/29 [==============================] - 0s 6ms/step - loss: 0.3533 - accuracy: 0.8503 - val_loss: 0.3433 - val_accuracy: 0.8500
# Epoch 6/15
# 29/29 [==============================] - 0s 5ms/step - loss: 0.3492 - accuracy: 0.8552 - val_loss: 0.3682 - val_accuracy: 0.8431
# Epoch 7/15
# 29/29 [==============================] - 0s 5ms/step - loss: 0.3362 - accuracy: 0.8569 - val_loss: 0.3291 - val_accuracy: 0.8556
# Epoch 8/15
# 29/29 [==============================] - 0s 5ms/step - loss: 0.3369 - accuracy: 0.8569 - val_loss: 0.3556 - val_accuracy: 0.8472
# Epoch 9/15
# 29/29 [==============================] - 0s 5ms/step - loss: 0.3235 - accuracy: 0.8583 - val_loss: 0.3219 - val_accuracy: 0.8528
# Epoch 10/15
# 29/29 [==============================] - 0s 4ms/step - loss: 0.3131 - accuracy: 0.8674 - val_loss: 0.3234 - val_accuracy: 0.8556
# Epoch 11/15
# 29/29 [==============================] - 0s 5ms/step - loss: 0.3051 - accuracy: 0.8726 - val_loss: 0.3119 - val_accuracy: 0.8625
# Epoch 12/15
# 29/29 [==============================] - 0s 5ms/step - loss: 0.3085 - accuracy: 0.8684 - val_loss: 0.3138 - val_accuracy: 0.8611
# Epoch 13/15
# 29/29 [==============================] - 0s 4ms/step - loss: 0.2957 - accuracy: 0.8764 - val_loss: 0.3057 - val_accuracy: 0.8694
# Epoch 14/15
# 29/29 [==============================] - 0s 5ms/step - loss: 0.2979 - accuracy: 0.8799 - val_loss: 0.3709 - val_accuracy: 0.8514
# Epoch 15/15
# 29/29 [==============================] - 0s 5ms/step - loss: 0.3017 - accuracy: 0.8778 - val_loss: 0.3022 - val_accuracy: 0.8681

# %%
helper.plotTrain(history1,Model_Name)
# Out:
# (<Figure size 864x360 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000276A8675BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000276A8F8B100>],
#        dtype=object))

# %% [markdown]
# ## How many weights in this model ?
#
# **Question:** Calculate the number of parameters in your new model.
#
# Set variable `num_parameters1` to be equal to the number of parameters in your model.

# %%
# Set num_parameters1 equal to the number of weights in the model
num_parameters1 = None

# YOUR CODE HERE
num_parameters1=model1.count_params()

print('Parameters number in model1:', num_parameters1)
# Out:
# Parameters number in model1: 204865

# %% [markdown]
# ## Evaluate the model
#
# **Question:**
#
# Evaluate the new model using the test dataset. Please store the model score in a variable named `score1`.

# %%
score1 = []

# YOUR CODE HERE
score1=model1.evaluate(X_test,y_test)

print("{n:s}: Test loss: {l:3.2f} / Test accuracy: {a:3.2f}".format(n=model_name1, l=score1[0], a=score1[1]))
# Out:
# 13/13 [==============================] - 0s 997us/step - loss: 0.2944 - accuracy: 0.8900
# Dense + Head: Test loss: 0.29 / Test accuracy: 0.89

# %% [markdown]
# Your new test score should be at least 0.8

# %% [markdown]
# # Save your trained model1 and history1

# %%
helper.saveModel(model1, model_name1)
helper.saveHistory(history1, model_name1)
# Out:
# Directory .\models\Dense + Head already exists, files will be over-written.
# Model saved in directory .\models\Dense + Head; create an archive of this directory and submit with your assignment.
# Directory .\models\Dense + Head already exists, files will be over-written.

# %% [markdown]
# ## Your own model (Optional)
# Now you can build your own model using what you have learned from the course. Some ideas to try:
# - Try more than one additional `Dense` layer
# - Change the number of units (features) of your `Dense` layers.
# - Add `Dropout` layers; vary the parameter
# - Change the activation function
# - Change the classifier
# - ...
#
# Observe the effect of each change on the Loss and Accuracy.
#
# - You may want to use early stopping in training
#     - In order to stop training when model metrics *worsen* rather than *improve*

# %% [markdown]
# Comments: Based on the former two models above, it seems that adding more dense layers could work better.

# %%
## I try a new model wit 2 dense layers + 1 head dense layers:
model_my = None
num_features_my = 64

from tensorflow.keras.layers import Dropout
# YOUR CODE HERE
model_my=keras.Sequential([
    keras.layers.Flatten(input_shape=(80,80)), # transforms the format of the images from a 2-dimensional array to a 1-dimensional array
    ##keras.layers.Dropout(0.1, noise_shape=None, seed=None),
    keras.layers.Dense(num_features_my,activation='relu',name="dense_my1"),
    keras.layers.Dropout(0.4, noise_shape=None, seed=None),
    keras.layers.Dense(num_features_my,activation='relu',name="dense_my2"),
    keras.layers.Dropout(0.4, noise_shape=None, seed=None),
    ##keras.layers.Dense(num_features_my,activation='relu',name="dense_my3"),
    ##keras.layers.Dropout(0.3, noise_shape=None, seed=None),
    # I know that the head layer output_size=2 using loss='sparse_categorical_crossentropy'; Since I choose loss='binary_crossentropy', thus here output_size is set to 1)
    keras.layers.Dense(1, activation='relu',name="dense_head_my")]) # Head layer for classification

model_my.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_2 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_my1 (Dense)            (None, 64)                409664
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_my2 (Dense)            (None, 64)                4160
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_head_my (Dense)        (None, 1)                 65
# =================================================================
# Total params: 413,889
# Trainable params: 413,889
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Plot your model
plot_model(model_my)

# %%
model_name3 = "two additional dense + Head layers"

# YOUR CODE HERE
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
es_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=.00005, patience=2, verbose=0, mode='auto', baseline=None, restore_best_weights=True)

callbacks = [ es_callback,
             ModelCheckpoint(filepath=model_name3 + ".ckpt", monitor='acc', save_best_only=True)
           ]

## Split data into train and valid again:
X_train_3, X_valid_3, y_train_3, y_valid_3 = train_test_split(X_train, y_train, test_size=0.20, random_state=42)


metrics = ['accuracy']
model_my.compile(optimizer='adam',
                    loss='binary_crossentropy',
                    metrics=metrics)

n_epochs = 15
batch_size = 100
history3 =model0.fit(X_train_3, y_train_3, epochs=n_epochs, validation_data=(X_valid_3, y_valid_3), shuffle=True, callbacks=callbacks,batch_size=batch_size)
# Out:
# Epoch 1/15
# 18/29 [=================>............] - ETA: 0s - loss: 0.2879 - accuracy: 0.8828WARNING:tensorflow:Can save best model only with acc available, skipping.
# 29/29 [==============================] - 0s 5ms/step - loss: 0.2974 - accuracy: 0.8799 - val_loss: 0.3065 - val_accuracy: 0.8681
# Epoch 2/15
# 21/29 [====================>.........] - ETA: 0s - loss: 0.3023 - accuracy: 0.8700WARNING:tensorflow:Can save best model only with acc available, skipping.
# 29/29 [==============================] - 0s 3ms/step - loss: 0.3067 - accuracy: 0.8715 - val_loss: 0.3100 - val_accuracy: 0.8653
# Epoch 3/15
# 24/29 [=======================>......] - ETA: 0s - loss: 0.2921 - accuracy: 0.8788WARNING:tensorflow:Can save best model only with acc available, skipping.
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2923 - accuracy: 0.8795 - val_loss: 0.3088 - val_accuracy: 0.8667

# %%
helper.plotTrain(history3,model_name3)
# Out:
# (<Figure size 864x360 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000276A8AC9A00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000276A8B542B0>],
#        dtype=object))

# %%
score1 = []

# YOUR CODE HERE
score1=model_my.evaluate(X_test,y_test)

print("{n:s}: Test loss: {l:3.2f} / Test accuracy: {a:3.2f}".format(n=model_name3, l=score1[0], a=score1[1]))
# Out:
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6797 - accuracy: 0.7350
# two additional dense + Head layers: Test loss: 0.68 / Test accuracy: 0.74

# %% [markdown]
# **Comments:**
# Based on the results of my model:
# 1. Training performance gets improved when adding an additional layers, which can be about 95% accuracy;
# 2. Test result is not satisfying, which keeps around 75%, much lower than 89% test accuracy from model1 result, probably due to overfitting; Although I have tried dropout layers, the overfitting problem still exists.
# 3. I have tried dropouts between each layers and varied serveral drop percentage values, but the test accuracy still could not get much improved.
# 4. Thus, I conclude, in this case adding more layers would worse prediction performance. Keeping just Head layer or one dense+head perform better.
